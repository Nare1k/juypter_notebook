# %%
import random

random = random.randint(1, 10) # Creates a random number between 1 and 10 using the random module.
while guess != random: # Creates a while loop while the guess does not equal to the random number.
    guess = int(input("What is your guess?"))
    if guess > random: # If guess higher than the random number
        print("Too high! Try again.")
    elif guess < random: # If guess is lower than the random number
        print("Too low! Try again.")
    elif guess == random: # If guess is equal to the random number
        print("Your guess is correct!")
